# %% [markdown]
# <a href="https://colab.research.google.com/github/valy3124/SupervisedLearning/blob/main/Fundamentals_ML_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Setul de date
#
# Bolile cardiovasculare(BCV) sunt cea mai importantă cauză de deces la nivel global, provocând aproximativ 17,9 milioane de vieți pierdute în fiecare an, ceea ce reprezintă 31% din toate decesele la nivel mondial. Insuficiența cardiacă este un eveniment comun cauzat de BCV, iar acest set de date conține 12 caracteristici care pot fi utilizate pentru a prezice mortalitatea cauzată de insuficiența cardiacă.
#
# Cele mai multe boli cardiovasculare pot fi prevenite prin abordarea factorilor de risc comportamentali, cum ar fi consumul de tutun, dieta nesănătoasă și obezitatea, inactivitatea fizică și consumul nociv de alcool, prin strategii la nivel de populație.
#
# Persoanele cu boli cardiovasculare sau cele care au un risc cardiovascular ridicat (datorită prezenței unuia sau mai multor factori de risc, cum ar fi hipertensiunea, diabetul, hiperlipidemia sau o boală deja stabilită) au nevoie de detectare timpurie și gestionare, în care un model de învățare automată poate fi de mare ajutor.

# %%
# !unzip Data.zip -d Data
# Out:
# Archive:  Data.zip
#    creating: Data/Brain Tumor Data Set/
#    creating: Data/Brain Tumor Data Set/Brain Tumor/
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1).png
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1).tif
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (10).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (10).tif
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (100).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1000).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1001).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1002).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1003).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1004).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1005).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1006).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1007).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1008).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1009).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (101).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1010).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1011).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1012).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1013).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1014).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1015).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1016).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1017).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1018).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1019).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (102).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1020).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1021).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1022).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1023).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1024).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1025).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1026).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1027).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1028).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1029).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (103).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1030).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1031).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1032).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1033).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1034).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1035).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1036).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1037).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1038).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1039).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (104).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1040).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1041).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1042).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1043).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1044).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1045).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1046).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1047).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1048).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1049).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (105).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1050).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1051).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1052).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1053).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1054).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1055).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1056).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1057).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1058).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1059).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (106).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1060).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1061).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1062).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1063).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1064).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1065).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1066).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1067).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1068).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1069).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (107).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1070).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1071).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1072).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1073).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1074).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1075).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1076).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1077).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1078).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1079).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (108).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1080).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1081).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1082).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1083).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1084).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1085).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1086).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1087).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1088).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1089).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (109).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1090).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1091).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1092).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1093).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1094).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1095).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1096).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1097).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1098).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1099).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (11).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (11).tif
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (110).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1100).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1101).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1102).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1103).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1104).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1105).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1106).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1107).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1108).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1109).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (111).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1110).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1111).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1112).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1113).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1114).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1115).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1116).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1117).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1118).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1119).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (112).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1120).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1121).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1122).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1123).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1124).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1125).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1126).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1127).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1128).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1129).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (113).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1130).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1131).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1132).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1133).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1134).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1135).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1136).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1137).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1138).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1139).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (114).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1140).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1141).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1142).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1143).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1144).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1145).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1146).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1147).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1148).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1149).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (115).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1150).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1151).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1152).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1153).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1154).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1155).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1156).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1157).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1158).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1159).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (116).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1160).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1161).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1162).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1163).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1164).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1165).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1166).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1167).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1168).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1169).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (117).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1170).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1171).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1172).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1173).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1174).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1175).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1176).JPG
#  extracting: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1177).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1178).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1179).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (118).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1180).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1181).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1182).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1183).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1184).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1185).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1186).JPG
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1187).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1188).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1189).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (119).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1190).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1191).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1192).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1193).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1194).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1195).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1196).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1197).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1198).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (1199).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer (12).jpg
#   inflating: Data/Brain Tumor Data Set/Brain Tumor/Cancer

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2024)
train_df = pd.concat([X_train.reset_index(drop=True), y_train.reset_index(drop=True)], axis=1)
train_df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  64.0        0                      1610         0                 60
# 1  65.0        1                       135         0                 35
# 2  60.0        1                      2281         1                 40
# 3  65.0        0                       395         1                 25
# 4  50.0        1                       249         1                 35
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    0   242000.0               1.0           137    1
# 1                    1   290000.0               0.8           134    1
# 2                    0   283000.0               1.0           141    0
# 3                    0   265000.0               1.2           136    1
# 4                    1   319000.0               1.0           128    0
#
#    smoking  time  DEATH_EVENT
# 0        0   113            0
# 1        0   194            0
# 2        0   187            0
# 3        1   154            1
# 4        0    28            1

# %% [markdown]
# #### EDA

# %%
descriptive = pd.DataFrame(round(train_df.describe(include='all'),3).T)

descriptive
# Out:
#                           count        mean        std      min       25%  \
# age                       239.0      61.022     11.981     40.0      52.0
# anaemia                   239.0       0.452      0.499      0.0       0.0
# creatinine_phosphokinase  239.0     606.481   1001.323     23.0     114.0
# diabetes                  239.0       0.439      0.497      0.0       0.0
# ejection_fraction         239.0      38.410     11.851     14.0      30.0
# high_blood_pressure       239.0       0.356      0.480      0.0       0.0
# platelets                 239.0  264928.773  98741.346  25100.0  214000.0
# serum_creatinine          239.0       1.398      0.991      0.6       0.9
# serum_sodium              239.0     136.703      4.523    113.0     134.0
# sex                       239.0       0.653      0.477      0.0       0.0
# smoking                   239.0       0.314      0.465      0.0       0.0
# time                      239.0     125.749     77.386      6.0      65.0
# DEATH_EVENT               239.0       0.351      0.478      0.0       0.0
#
#                                50%        75%       max
# age                           60.0      70.00      95.0
# anaemia                        0.0       1.00       1.0
# creatinine_phosphokinase     260.0     582.00    7861.0
# diabetes                       0.0       1.00       1.0
# ejection_fraction             38.0      45.00      80.0
# high_blood_pressure            0.0       1.00       1.0
# platelets                 257000.0  305000.00  850000.0
# serum_creatinine               1.1       1.45       9.0
# serum_sodium                 137.0     140.00     148.0
# sex                            1.0       1.00       1.0
# smoking                        0.0       1.00       1.0
# time                         109.0     197.00     285.0
# DEATH_EVENT                    0.0       1.00       1.0

# %%
fig, ax = plt.subplots(4,4, figsize=(20,20))

ax = ax.flatten()

for i,var in enumerate(train_df.columns):

    sns.histplot(data=train_df, x=var, ax=ax[i])

    ax[i].set_title(var)

for j in range(len(train_df.columns), len(ax)):
    fig.delaxes(ax[j])

plt.tight_layout()
plt.show()

# %%
num_vars = train_df.columns.difference(['anaemia', 'diabetes', 'high_blood_pressure', 'sex', 'smoking', 'DEATH_EVENT'])

cat_vars = train_df.columns.difference(num_vars)


fig, ax = plt.subplots(3,3, figsize=(20,20))

ax = ax.flatten()

for i, var in enumerate(num_vars):

    sns.boxplot(data=train_df, x=var, ax=ax[i])

    ax[i].set_title(f'The boxplot of {var}')

for j in range(len(num_vars), len(ax)):
    fig.delaxes(ax[j])

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(3,3,figsize=(20,20))

ax = ax.flatten()

for i, var in enumerate(num_vars):
    sns.kdeplot(data=train_df, x=var, hue='DEATH_EVENT', ax=ax[i])
    ax[i].set_title(f'The distribution of {var}')

plt.tight_layout()

plt.show()

# %%
fig, ax = plt.subplots(2,3, figsize=(16,12))

ax = ax.flatten()

cat_vars = train_df.columns.difference(num_vars).difference(['DEATH_EVENT'])

for i, var in enumerate(cat_vars):
    pd.crosstab(train_df[var], train_df['DEATH_EVENT'], normalize='index').plot(kind='bar', stacked=True, ax=ax[i])
    ax[i].set_title(f'P(Heart stroke given {var})')

plt.tight_layout()

plt.show()

# %% [markdown]
# Checking for correlations

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(round(train_df.corr(),2), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# #### PCA
# Principal component analysis (PCA) reduce numărul de dimensiuni în seturi de date la componente principale care păstrează cea mai mare parte a informației originale. Acest lucru se realizează prin transformarea variabilelor potențial corelate într-un set mai mic de variabile, numit componente principale.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# StandardScaler: Acesta este utilizat pentru a standardiza datele prin scalarea caracteristicilor astfel încât să aibă o medie de 0 și o deviație standard de 1. Standardizarea este esențială pentru PCA, care este sensibil la scara caracteristicilor.

# %%
# Reduce dimensions
reduced_variables = ['time','ejection_fraction','age','serum_creatinine','creatinine_phosphokinase','sex','smoking','serum_sodium','high_blood_pressure']
pca_ready = train_df[reduced_variables]

# Scaled data

scaler = StandardScaler()

pca_ready = scaler.fit_transform(pca_ready)

# %%
pca = PCA()

train_pca_fitted = pca.fit_transform(pca_ready)

# %%
cumulative_variance = np.cumsum(pca.explained_variance_ratio_)

fig, ax = plt.subplots(figsize=(6,6))

sns.lineplot(x= range(1,len(cumulative_variance)+1), y=cumulative_variance, ax=ax, marker='o')

plt.title(f'Cumulative variance explained by components')

plt.tight_layout()

plt.show()

# %%
#Refit with n_components = 6 to capture 80% variance of original training data

pca = PCA(n_components=6)

train_pca_fitted = pca.fit_transform(pca_ready)

test_pca_fitted = pca.transform(scaler.transform(X_test[reduced_variables]))

# %%
train_pca_fitted = pd.DataFrame(train_pca_fitted, columns=['PC1','PC2','PC3','PC4','PC5','PC6'])

train_pca_fitted['DEATH_EVENT'] = train_df['DEATH_EVENT']

# %%
train_pca_fitted.corr()

sns.heatmap(round(train_pca_fitted.corr(),2), annot=True, cmap='coolwarm')

plt.title('Correlation Matrix')

plt.show()

# %%
sns.pairplot(data=train_pca_fitted, hue='DEATH_EVENT')

# %% [markdown]
# ### Model Training

# %%
premodel_scaler = StandardScaler()

X_train_scaled = premodel_scaler.fit_transform(X_train[reduced_variables])
X_test_scaled = premodel_scaler.transform(X_test[reduced_variables])

# %%
X_train_scaled.shape, X_test_scaled.shape
# Out:
# ((239, 9), (60, 9))

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# ### Exercițiul 1
#
# Definiti urmatoarele modele de clasificare

# %%
Models = {

    'Logistic Regression': LogisticRegression(),

    'Decision Tree': DecisionTreeClassifier(),

    'Random Forest': RandomForestClassifier(),

    'KNN': KNeighborsClassifier(),

    'XGBoost': XGBClassifier(),

    'Naive Bayes': GaussianNB()
}

# %% [markdown]
# ### Exercițiul 2
#
# a) Antrenează modelul: Folosește metoda fit() pentru a antrena modelul specificat pe datele de antrenament scalate, X_train_scaled și etichetele de antrenament, y_train.
#
# b) Utilizează metoda predict() pentru a genera predicții pe setul de testare scalat, X_test_scaled.
#
# c) Stochează în dicționarul results numele modelului ca cheie și un tuplu care conține recall-ul și precision-ul obținut pe setul de testare.

# %%
results = {}

for model_name, model in Models.items():

    # TO DO a)
    model.fit(X_train_scaled, y_train)

    y_pred = model.predict(X_test_scaled)
    # TO DO b)


    results[model_name] = (recall_score(y_test, y_pred, pos_label=1), precision_score(y_test, y_pred, pos_label=1))

print("Recall, Precision")
print(results)
# Out:
# Recall, Precision
# {'Logistic Regression': (0.8333333333333334, 0.6666666666666666), 'Decision Tree': (0.5833333333333334, 0.4117647058823529), 'Random Forest': (0.75, 0.6923076923076923), 'KNN': (0.6666666666666666, 0.5333333333333333), 'XGBoost': (0.6666666666666666, 0.7272727272727273), 'Naive Bayes': (0.75, 0.9)}

# %%
# Results on original data without PCA

results = {}

for model_name, model in Models.items():

    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    results[model_name] = (recall_score(y_test, y_pred, pos_label=1), precision_score(y_test, y_pred, pos_label=1))

print("Recall, Precision")
results
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Recall, Precision
# {'Logistic Regression': (0.5833333333333334, 0.6363636363636364),
#  'Decision Tree': (0.5, 0.4),
#  'Random Forest': (0.6666666666666666, 0.6666666666666666),
#  'KNN': (0.4166666666666667, 0.3333333333333333),
#  'XGBoost': (0.6666666666666666, 0.6153846153846154),
#  'Naive Bayes': (0.6666666666666666, 0.8)}

# %% [markdown]
# L1 regularization (Lasso regularization) adds a penalty equal to the absolute values of the coefficients, which can shrink some coefficients to exactly zero, effectively performing feature selection.
#
# L2 regularization (Ridge regularization) adds a penalty equal to the sum of the squares of the coefficients. This discourages large coefficient values, effectively shrinking them towards zero without making them exactly zero. L2 regularization generally helps in cases where the features have a moderate level of collinearity.
#
# C=0.05 controls the strength of regularization. Smaller values of C mean stronger regularization.
# In general, this configuration helps produce a simpler model that generalizes better to new data, especially when working with datasets where there is a risk of overfitting or noisy features.

# %%
best_model = LogisticRegression(penalty='l2',C=.02)
best_model.fit(X_train_scaled, y_train)
y_pred = best_model.predict(X_test_scaled)
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
print(f'Precision: {precision_score(y_test, y_pred, pos_label=1)}')
print(f'Recall: {recall_score(y_test, y_pred, pos_label=1)}')
print(f'F1 score: {f1_score(y_test, y_pred, pos_label=1)}')
# Out:
# Accuracy: 0.95
# Precision: 1.0
# Recall: 0.75
# F1 score: 0.8571428571428571

# %% [markdown]
# ### Exercițiul 3
# Afisati matricea de confuzie pentru predictia realizata cu modelul best_model

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=best_model.classes_)
disp.plot()
plt.show()

# %% [markdown]
# ### Neural Networks

# %% [markdown]
# Diferite tipuri de optimizatori, functii de loss

# %%
# !pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl.metadata (6.2 kB)
# Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import os # A module that provides a way to interact with the operating system, allowing for tasks such as file and directory manipulation.
import torch
from PIL import Image # A module from the Python Imaging Library (PIL) that provides functionality for opening, manipulating, and saving various image file formats.
from torch.utils.data import Dataset # A PyTorch class that represents a dataset and provides an interface for accessing and processing the data during training.
import torchvision
import torchvision.transforms as transforms # A module from the torchvision library that provides common image transformations, such as resizing, cropping, and normalization.
from torch.utils.data import random_split # A function from PyTorch that allows for randomly splitting a dataset into training and validation subsets.
from torch.optim.lr_scheduler import ReduceLROnPlateau # A PyTorch scheduler that adjusts the learning rate during training based on a specified metric, reducing it when the metric plateaus.
import torch.nn as nn # A module in PyTorch that provides classes for defining and building neural networks.
from torchvision import utils # A module from torchvision that contains utility functions for working with images, such as saving and visualizing them.
from torchvision.datasets import ImageFolder
import splitfolders
from torchsummary import summary
import torch.nn.functional as F
import pathlib
from sklearn.metrics import confusion_matrix, classification_report
import itertools # This import statement imports the itertools module, which provides functions for efficient looping and combining of iterables. It can be used for tasks such as generating combinations or permutations of elements.
from tqdm.notebook import trange, tqdm # These functions allow for the creation of progress bars to track the progress of loops or tasks.
from torch import optim
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Dataset
# Citirea datelor

# %%
labels_df = pd.read_csv('Data/metadata.csv')
print(labels_df.head().to_markdown())
# Out:
# |    |   Unnamed: 0 | image           | class   | format   | mode   | shape         |
# |---:|-------------:|:----------------|:--------|:---------|:-------|:--------------|
# |  0 |            0 | Cancer (1).jpg  | tumor   | JPEG     | RGB    | (512, 512, 3) |
# |  1 |            1 | Cancer (1).png  | tumor   | PNG      | L      | (300, 240)    |
# |  2 |            2 | Cancer (1).tif  | tumor   | TIFF     | RGB    | (256, 256, 3) |
# |  3 |            3 | Cancer (10).jpg | tumor   | JPEG     | RGB    | (512, 512, 3) |
# |  4 |            4 | Cancer (10).tif | tumor   | TIFF     | RGB    | (256, 256, 3) |

# %%
os.listdir('Data/Brain Tumor Data Set')
# Out:
# ['Healthy', 'Brain Tumor']

# %%
labels_df.shape
# Out:
# (4600, 6)

# %% [markdown]
# Procesarea setului de date

# %%
data_dir = 'Data/Brain Tumor Data Set'
data_dir = pathlib.Path(data_dir)

splitfolders.ratio(data_dir, output='brain', seed=20, ratio=(0.8, 0.2))

data_dir = 'brain'
data_dir = pathlib.Path(data_dir)
# Out:
# Copying files: 4600 files [00:00, 6213.47 files/s]

# %% [markdown]
# ### Exercițiul 4
# Creează o variabilă numită transform, care să conțină o secvență de transformări aplicate fiecărei imagini, după cum urmează:
#
# Redimensionare: Redimensionează fiecare imagine la 256x256 pixeli.
#
# Flip orizontal: Aplică o întoarcere orizontală aleatorie, cu probabilitatea de 50%.
#
# Flip vertical: Aplică o întoarcere verticală aleatorie, cu probabilitatea de 50%.
#
# Rotire aleatorie: Aplică o rotație aleatorie în intervalul de ±30 de grade.
#
# Conversie în tensor: Convertește imaginea într-un tensor utilizabil de PyTorch.
#
# Normalizare: Normalizează valorile pixelilor folosind media [0.485, 0.456, 0.406] și deviația standard [0.229, 0.224, 0.225], pentru a asigura compatibilitatea cu un model pre-antrenat.
#
# Folosește transforms.Compose() pentru a crea acest pipeline de transformări și asignează-l variabilei transform.

# %%
#TODO 4
import torchvision.transforms as transforms

transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.RandomRotation(degrees=30),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
train_set = torchvision.datasets.ImageFolder(data_dir.joinpath("train"), transform=transform)
train_set.transform
val_set = torchvision.datasets.ImageFolder(data_dir.joinpath("val"), transform=transform)
val_set.transform
# Out:
# Compose(
#     Resize(size=(256, 256), interpolation=bilinear, max_size=None, antialias=True)
#     RandomHorizontalFlip(p=0.5)
#     RandomVerticalFlip(p=0.5)
#     RandomRotation(degrees=[-30.0, 30.0], interpolation=nearest, expand=False, fill=0)
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# )

# %%
CLA_label = {
    0 : 'Brain Tumor',
    1 : 'Healthy'
}
figure = plt.figure(figsize=(10, 10))
cols, rows = 4, 4
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(train_set), size=(1,)).item()
    img, label = train_set[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(CLA_label[label])
    plt.axis("off")
    img_np = img.numpy().transpose((1, 2, 0))
    # Clip pixel values to [0, 1]
    img_valid_range = np.clip(img_np, 0, 1)
    plt.imshow(img_valid_range)
    plt.suptitle('Brain Images', y=0.95)
plt.show()

# %% [markdown]
# Dataloaders

# %%
batch_size = 64

train_loader = torch.utils.data.DataLoader(train_set, batch_size = batch_size, shuffle = True, num_workers = 2)
val_loader = torch.utils.data.DataLoader(val_set, batch_size = batch_size, shuffle = True, num_workers = 2)

# %%
for key, value in {'Training data': train_loader, "Validation data": val_loader}.items():
    for X, y in value:
        print(f"{key}:")
        print(f"Shape of X : {X.shape}")
        print(f"Shape of y: {y.shape} {y.dtype}\n")
        break
# Out:
# Training data:
# Shape of X : torch.Size([64, 3, 256, 256])
# Shape of y: torch.Size([64]) torch.int64
#
# Validation data:
# Shape of X : torch.Size([64, 3, 256, 256])
# Shape of y: torch.Size([64]) torch.int64

# %% [markdown]
# #### Arhitectura

# %%
'''This function can be useful in determining the output size of a convolutional layer in a neural network,
given the input dimensions and the convolutional layer's parameters.'''

def findConv2dOutShape(hin,win,conv,pool=2):
    # get conv arguments
    kernel_size = conv.kernel_size
    stride=conv.stride
    padding=conv.padding
    dilation=conv.dilation

    hout=np.floor((hin+2*padding[0]-dilation[0]*(kernel_size[0]-1)-1)/stride[0]+1)
    wout=np.floor((win+2*padding[1]-dilation[1]*(kernel_size[1]-1)-1)/stride[1]+1)

    if pool:
        hout/=pool
        wout/=pool
    return int(hout),int(wout)

# %%
class CNN_TUMOR(nn.Module):

    def __init__(self, params):

        super(CNN_TUMOR, self).__init__()

        Cin,Hin,Win = params["shape_in"]
        init_f = params["initial_filters"]
        num_fc1 = params["num_fc1"]
        num_classes = params["num_classes"]
        self.dropout_rate = params["dropout_rate"]

        self.conv1 = nn.Conv2d(Cin, init_f, kernel_size=3)
        h,w=findConv2dOutShape(Hin,Win,self.conv1)
        self.conv2 = nn.Conv2d(init_f, 2*init_f, kernel_size=3)
        h,w=findConv2dOutShape(h,w,self.conv2)
        self.conv3 = nn.Conv2d(2*init_f, 4*init_f, kernel_size=3)
        h,w=findConv2dOutShape(h,w,self.conv3)
        self.conv4 = nn.Conv2d(4*init_f, 8*init_f, kernel_size=3)
        h,w=findConv2dOutShape(h,w,self.conv4)

        self.num_flatten=h*w*8*init_f
        self.fc1 = nn.Linear(self.num_flatten, num_fc1)
        self.fc2 = nn.Linear(num_fc1, num_classes)

    def forward(self,X):

        X = F.relu(self.conv1(X));
        X = F.max_pool2d(X, 2, 2)
        X = F.relu(self.conv2(X))
        X = F.max_pool2d(X, 2, 2)
        X = F.relu(self.conv3(X))
        X = F.max_pool2d(X, 2, 2)
        X = F.relu(self.conv4(X))
        X = F.max_pool2d(X, 2, 2)
        X = X.view(-1, self.num_flatten)
        X = F.relu(self.fc1(X))
        X = F.dropout(X, self.dropout_rate)
        X = self.fc2(X)
        return F.log_softmax(X, dim=1)

# %% [markdown]
# ### Exercițiul 5
# Instanțiați rețeaua și asigurați-vă că aceasta rulează pe un GPU, dacă acesta este disponibil.

# %%
params_model={
        "shape_in": (3,256,256),
        "initial_filters": 8,
        "num_fc1": 100,
        "dropout_rate": 0.25,
        "num_classes": 2}

cnn_model = CNN_TUMOR(params_model)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")# TO DO
model = cnn_model.to(device)

# %%
summary(cnn_model, input_size=(3, 256, 256),device=device.type)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 8, 254, 254]             224
#             Conv2d-2         [-1, 16, 125, 125]           1,168
#             Conv2d-3           [-1, 32, 60, 60]           4,640
#             Conv2d-4           [-1, 64, 28, 28]          18,496
#             Linear-5                  [-1, 100]       1,254,500
#             Linear-6                    [-1, 2]             202
# ================================================================
# Total params: 1,279,230
# Trainable params: 1,279,230
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 7.11
# Params size (MB): 4.88
# Estimated Total Size (MB): 12.74
# ----------------------------------------------------------------

# %% [markdown]
# ### Exercițiul 6
# Definiți funcția de pierdere (*loss function*) și optimizatorul Adam cu valoarea parametrului learning rate = 3e-4 pentru antrenarea modelului.

# %%
loss_func = nn.CrossEntropyLoss()

# %%
opt = optim.Adam(cnn_model.parameters(), lr=3e-4)# Adam optimizer
lr_scheduler = ReduceLROnPlateau(opt, mode='min',factor=0.5, patience=20,verbose=1)

# %%
# Function to get the learning rate
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']

# Function to compute the loss value per batch of data
def loss_batch(loss_func, output, target, opt=None):

    loss = loss_func(output, target) # get loss
    pred = output.argmax(dim=1, keepdim=True) # Get Output Class
    metric_b=pred.eq(target.view_as(pred)).sum().item() # get performance metric

    if opt is not None:
        opt.zero_grad()
        loss.backward()
        opt.step()

    return loss.item(), metric_b

# Compute the loss value & performance metric for the entire dataset (epoch)
def loss_epoch(model,loss_func,dataset_dl,opt=None):

    run_loss=0.0
    t_metric=0.0
    len_data=len(dataset_dl.dataset)

    # internal loop over dataset
    for xb, yb in dataset_dl:
        # move batch to device
        xb=xb.to(device)
        yb=yb.to(device)
        output=model(xb) # get model output
        loss_b,metric_b=loss_batch(loss_func, output, yb, opt) # get loss per batch
        run_loss+=loss_b        # update running loss

        if metric_b is not None: # update running metric
            t_metric+=metric_b

    loss=run_loss/float(len_data)  # average loss value
    metric=t_metric/float(len_data) # average metric value

    return loss, metric

# %%
def Train_Val(model, params,verbose=False):

    # Get the parameters
    epochs=params["epochs"]
    loss_func=params["f_loss"]
    opt=params["optimiser"]
    train_dl=params["train"]
    val_dl=params["val"]
    lr_scheduler=params["lr_change"]
    weight_path=params["weight_path"]

    # history of loss values in each epoch
    loss_history={"train": [],"val": []}
    # histroy of metric values in each epoch
    metric_history={"train": [],"val": []}
    # a deep copy of weights for the best performing model
    best_model_wts = copy.deepcopy(model.state_dict())
    # initialize best loss to a large value
    best_loss=float('inf')

# Train Model n_epochs (the progress of training by printing the epoch number and the associated learning rate. It can be helpful for debugging, monitoring the learning rate schedule, or gaining insights into the training process.)

    for epoch in tqdm(range(epochs)):

        # Get the Learning Rate
        current_lr=get_lr(opt)
        if(verbose):
            print('Epoch {}/{}, current lr={}'.format(epoch, epochs - 1, current_lr))


# Train Model Process


        model.train()
        train_loss, train_metric = loss_epoch(model,loss_func,train_dl,opt)

        # collect losses
        loss_history["train"].append(train_loss)
        metric_history["train"].append(train_metric)


# Evaluate Model Process


        model.eval()
        with torch.no_grad():
            val_loss, val_metric = loss_epoch(model,loss_func,val_dl)

        # store best model
        if(val_loss < best_loss):
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())

            # store weights into a local file
            torch.save(model.state_dict(), weight_path)
            if(verbose):
                print("Copied best model weights!")

        # collect loss and metric for validation dataset
        loss_history["val"].append(val_loss)
        metric_history["val"].append(val_metric)

        # learning rate schedule
        lr_scheduler.step(val_loss)
        if current_lr != get_lr(opt):
            if(verbose):
                print("Loading best model weights!")
            model.load_state_dict(best_model_wts)

        if(verbose):
            print(f"train loss: {train_loss:.6f}, dev loss: {val_loss:.6f}, accuracy: {100*val_metric:.2f}")
            print("-"*10)

    # load best model weights
    model.load_state_dict(best_model_wts)

    return model, loss_history, metric_history

# %%
import copy
# Define various parameters used for training and evaluation of a cnn_model

params_train={
 "train": train_loader,"val": val_loader,
 "epochs": 20,
 "optimiser": optim.Adam(cnn_model.parameters(),lr=3e-4),
 "lr_change": ReduceLROnPlateau(opt,
                                mode='min',
                                factor=0.5,
                                patience=20,
                                verbose=0),
 "f_loss": nn.NLLLoss(reduction="sum"),
 "weight_path": "weights.pt",
}

# train and validate the model
cnn_model,loss_hist,metric_hist = Train_Val(cnn_model,params_train)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
# Convergence History Plot
epochs=params_train["epochs"]
fig,ax = plt.subplots(1,2,figsize=(12,5))

sns.lineplot(x=[*range(1,epochs+1)],y=loss_hist["train"],ax=ax[0],label='loss_hist["train"]')
sns.lineplot(x=[*range(1,epochs+1)],y=loss_hist["val"],ax=ax[0],label='loss_hist["val"]')
sns.lineplot(x=[*range(1,epochs+1)],y=metric_hist["train"],ax=ax[1],label='Acc_hist["train"]')
sns.lineplot(x=[*range(1,epochs+1)],y=metric_hist["val"],ax=ax[1],label='Acc_hist["val"]')
# Out:
# <Axes: >

# %%
# define function For Classification Report
def Ture_and_Pred(val_loader, model):
    i = 0
    y_true = []
    y_pred = []
    for images, labels in val_loader:
        images = images.to(device)
        labels = labels.numpy()
        outputs = model(images)
        _, pred = torch.max(outputs.data, 1)
        pred = pred.detach().cpu().numpy()

        y_true = np.append(y_true, labels)
        y_pred = np.append(y_pred, pred)

    return y_true, y_pred


# check confusion matrix for error analysis
y_true, y_pred = Ture_and_Pred(val_loader, cnn_model)

print(classification_report(y_true, y_pred), '\n\n')
cm = confusion_matrix(y_true, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.94      0.94       503
#          1.0       0.93      0.93      0.93       418
#
#     accuracy                           0.93       921
#    macro avg       0.93      0.93      0.93       921
# weighted avg       0.93      0.93      0.93       921

# %%
# Confusion Matrix Plotting Function
def show_confusion_matrix(cm, CLA_label, title='Confusion matrix', cmap=plt.cm.YlGnBu):

    plt.figure(figsize=(10,7))
    plt.grid(False)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(CLA_label))

    plt.xticks(tick_marks, [f"{value}={key}" for key , value in CLA_label.items()], rotation=45)
    plt.yticks(tick_marks, [f"{value}={key}" for key , value in CLA_label.items()])

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, f"{cm[i,j]}\n{cm[i,j]/np.sum(cm)*100:.2f}%", horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.tight_layout()
    plt.show()

show_confusion_matrix(cm, CLA_label)

# %%
torch.save(cnn_model, "Brain_Tumor_model.pt")
